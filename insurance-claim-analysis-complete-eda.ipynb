# %% [markdown]
# <a href="https://www.kaggle.com/code/adityaramachandran27/insurance-claim-analysis-complete-eda?scriptVersionId=132143064" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/insurance-claim-analysis-demographic-and-health/insurance_data.csv

# %%
import seaborn as sns

# %%
df = pd.read_csv('/kaggle/input/insurance-claim-analysis-demographic-and-health/insurance_data.csv')

# %%
df.head()
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.0   male  23.2             91      Yes         0
# 1      1          2  24.0   male  30.1             87       No         0
# 2      2          3   NaN   male  33.3             82      Yes         0
# 3      3          4   NaN   male  33.7             80       No         0
# 4      4          5   NaN   male  34.1            100       No         0
#
#   smoker     region    claim
# 0     No  southeast  1121.87
# 1     No  southeast  1131.51
# 2     No  southeast  1135.94
# 3     No  northwest  1136.40
# 4     No  northwest  1137.01

# %% [markdown]
# ## Column Types
# - **Numerical** - Index, PatientID, age, bmi, bloodpressure, children, claim
# - **Categorical** - gender, diabetic, smoker, region

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Age

# %%
df['age'].describe()
# Out:
# count    1335.000000
# mean       38.078652
# std        11.102924
# min        18.000000
# 25%        29.000000
# 50%        38.000000
# 75%        47.000000
# max        60.000000
# Name: age, dtype: float64

# %%
sns.set(style='ticks', palette='Set2')
sns.displot(data=df, x='age', kind='hist', bins=22).set(title='Age distribution')

# %%
sns.displot(data=df,x='age',kind='kde', fill=True,color=sns.color_palette()[3]).set(title='Age distribution - KDE plot')

# %%
# calculating the skew

df['age'].skew()
# Out:
# 0.11361133741072633

# %%
df['age'].isnull().sum()
# Out:
# 5

# %% [markdown]
# **conclusions**
# - Age is normally (almost) distributed
# - Maximum number of people are aged between 25 - 50
# - There are less number of people aged between 38 - 40

# %% [markdown]
# ### BMI

# %%
df['bmi'].describe()
# Out:
# count    1340.000000
# mean       30.668955
# std         6.106735
# min        16.000000
# 25%        26.275000
# 50%        30.400000
# 75%        34.700000
# max        53.100000
# Name: bmi, dtype: float64

# %%
df['bmi'].isnull().sum()
# Out:
# 0

# %%
sns.displot(data=df, x='bmi', kind='hist', color=sns.color_palette()[2]).set(title='BMI distribution')

# %%
sns.displot(data=df, x='bmi', kind='kde', color=sns.color_palette()[4], fill=True).set(title='BME distribution - KDE Plot')

# %%
df['bmi'].skew()
# Out:
# 0.28597245020808587

# %%
df['bmi'].describe()
# Out:
# count    1340.000000
# mean       30.668955
# std         6.106735
# min        16.000000
# 25%        26.275000
# 50%        30.400000
# 75%        34.700000
# max        53.100000
# Name: bmi, dtype: float64

# %% [markdown]
#  If your BMI is less than 18.5, it falls within the underweight range. If your BMI is 18.5 to 24.9, it falls within the Healthy Weight range. If your BMI is 25.0 to 29.9, it falls within the overweight range. If your BMI is 30.0 or higher, it falls within the obese range ([Source](https://www.cdc.gov/healthyweight/assessing/index.html#:~:text=If%20your%20BMI%20is%20less,falls%20within%20the%20obese%20range.))
#
# - We can see from the study that general BMI range is from 18.5 to 24.9, but in our dataset, more than 50% of people have a BMI higher than 30 and the maximum is 53 which is extremely high
# - Let's take a closer look at these points

# %%
df[df['bmi'] > 26]
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# 5         5          6   NaN    male  34.4             96      Yes         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# 1        No  southeast   1131.51
# 2        No  southeast   1135.94
# 3        No  northwest   1136.40
# 4        No  northwest   1137.01
# 5        No  northwest   1137.47
# ...     ...        ...       ...
# 1335    Yes  northwest  55135.40
# 1336    Yes  northeast  58571.07
# 1337    Yes  northwest  60021.40
# 1338    Yes  southeast  62592.87
# 1339    Yes  southeast  63770.43
#
# [1017 rows x 11 columns]

# %%
sns.kdeplot(data=df, x='bmi', fill=True)
sns.rugplot(data=df, x='bmi', color=sns.color_palette()[5]).set(title='BMI distribution -KDE + Rug Plot')
# Out:
# [Text(0.5, 1.0, 'BMI distribution -KDE + Rug Plot')]

# %%
sns.boxplot(data=df, y='bmi').set(title='BMI distribution - Box Plot')
# Out:
# [Text(0.5, 1.0, 'BMI distribution - Box Plot')]

# %% [markdown]
# The boxplot says the median value is at 30 and the data has outliers over the value of 47 (around). This still seems really high and we will not this in our obervations

# %% [markdown]
# **conclusions**
# - The BMI is normally distributed
# - The BMI has very high values, values reaching over 45
# - Median iss at 30, which is considered as obese
# - no missing values

# %% [markdown]
# ### Bloodpressure

# %%
df['bloodpressure'].describe()
# Out:
# count    1340.000000
# mean       94.157463
# std        11.434712
# min        80.000000
# 25%        86.000000
# 50%        92.000000
# 75%        99.000000
# max       140.000000
# Name: bloodpressure, dtype: float64

# %%
sns.displot(data=df, x='bloodpressure', kind='hist', color=sns.color_palette()[6]).set(title='Bloodpressure distribution')

# %%
sns.displot(data=df, x='bloodpressure', kind='kde', color=sns.color_palette()[7], fill=True).set(title='Bloodpressure distribution - KDE Plot')

# %%
df['bloodpressure'].skew()
# Out:
# 1.4835342102293079

# %%
sns.catplot(data=df, y='bloodpressure', kind='box', color=sns.color_palette()[5]).set(title='Bloodpressure distribution - Box Plot')

# %% [markdown]
# There seem to lots of ouliers in the data according to the boxplot, lets check it out

# %%
df[df['bloodpressure'] > 120]
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 1147   1147       1148  29.0  female  32.7            128      Yes         2
# 1150   1150       1151  55.0  female  27.1            135       No         1
{
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_e66f8_row0_col1, #T_e66f8_row1_col0, #T_e66f8_row1_col2, #T_e66f8_row1_col3, #T_e66f8_row1_col4, #T_e66f8_row1_col6, #T_e66f8_row1_col8, #T_e66f8_row1_col10, #T_e66f8_row1_col12, #T_e66f8_row1_col13, #T_e66f8_row1_col15, #T_e66f8_row1_col17, #T_e66f8_row1_col18, #T_e66f8_row2_col0, #T_e66f8_row2_col1, #T_e66f8_row2_col2, #T_e66f8_row2_col3, #T_e66f8_row2_col4, #T_e66f8_row2_col5, #T_e66f8_row2_col6, #T_e66f8_row2_col7, #T_e66f8_row2_col8, #T_e66f8_row2_col9, #T_e66f8_row2_col10, #T_e66f8_row2_col11, #T_e66f8_row2_col12, #T_e66f8_row2_col13, #T_e66f8_row2_col14, #T_e66f8_row2_col15, #T_e66f8_row2_col16, #T_e66f8_row2_col17, #T_e66f8_row2_col18, #T_e66f8_row2_col19, #T_e66f8_row2_col20 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_e66f8_row0_col7, #T_e66f8_row1_col5, #T_e66f8_row1_col14 {
#   background-color: #ff7f00;
#   color: #f1f1f1;
# }
# #T_e66f8_row1_col16 {
#   background-color: #ff5500;
#   color: #f1f1f1;
# }
# #T_e66f8_row1_col19 {
#   background-color: #ff3f00;
#   color: #f1f1f1;
# }
# #T_e66f8_row1_col20 {
#   background-color: #ff3200;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e66f8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >bloodpressure</th>
#       <th id="T_e66f8_level0_col0" class="col_heading level0 col0" >121</th>
#       <th id="T_e66f8_level0_col1" class="col_heading level0 col1" >122</th>
#       <th id="T_e66f8_level0_col2" class="col_heading level0 col2" >123</th>
#       <th id="T_e66f8_level0_col3" class="col_heading level0 col3" >124</th>
#       <th id="T_e66f8_level0_col4" class="col_heading level0 col4" >125</th>
#       <th id="T_e66f8_level0_col5" class="col_heading level0 col5" >126</th>
#       <th id="T_e66f8_level0_col6" class="col_heading level0 col6" >127</th>
#       <th id="T_e66f8_level0_col7" class="col_heading level0 col7" >128</th>
#       <th id="T_e66f8_level0_col8" class="col_heading level0 col8" >129</th>
#       <th id="T_e66f8_level0_col9" class="col_heading level0 col9" >130</th>
#       <th id="T_e66f8_level0_col10" class="col_heading level0 col10" >131</th>
#       <th id="T_e66f8_level0_col11" class="col_heading level0 col11" >132</th>
#       <th id="T_e66f8_level0_col12" class="col_heading level0 col12" >133</th>
#       <th id="T_e66f8_level0_col13" class="col_heading level0 col13" >134</th>
#       <th id="T_e66f8_level0_col14" class="col_heading level0 col14" >135</th>
#       <th id="T_e66f8_level0_col15" class="col_heading level0 col15" >136</th>
#       <th id="T_e66f8_level0_col16" class="col_heading level0 col16" >137</th>
#       <th id="T_e66f8_level0_col17" class="col_heading level0 col17" >138</th>
#       <th id="T_e66f8_level0_col18" class="col_heading level0 col18" >139</th>
#       <th id="T_e66f8_level0_col19" class="col_heading level0 col19" >140</th>
#       <th id="T_e66f8_level0_col20" class="col_heading level0 col20" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >smoker</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e66f8_level0_row0" class="row_heading level0 row0" >No</th>
#       <td id="T_e66f8_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_e66f8_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_e66f8_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_e66f8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e66f8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e66f8_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_e66f8_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_e66f8_row0_col7" class="data row0 col7" >2</td>
#       <td id="T
{
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_0d839_row0_col2, #T_0d839_row0_col5, #T_0d839_row0_col6, #T_0d839_row0_col7, #T_0d839_row0_col14 {
#   background-color: #ff7f00;
#   color: #f1f1f1;
# }
# #T_0d839_row0_col18, #T_0d839_row1_col10 {
#   background-color: #ff5500;
#   color: #f1f1f1;
# }
# #T_0d839_row1_col3 {
#   background-color: #ffaa00;
#   color: #000000;
# }
# #T_0d839_row1_col19 {
#   background-color: #ff3f00;
#   color: #f1f1f1;
# }
# #T_0d839_row1_col20 {
#   background-color: #fff600;
#   color: #000000;
# }
# </style>
# <table id="T_0d839">
#   <thead>
#     <tr>
#       <th class="index_name level0" >bloodpressure</th>
#       <th id="T_0d839_level0_col0" class="col_heading level0 col0" >121</th>
#       <th id="T_0d839_level0_col1" class="col_heading level0 col1" >122</th>
#       <th id="T_0d839_level0_col2" class="col_heading level0 col2" >123</th>
#       <th id="T_0d839_level0_col3" class="col_heading level0 col3" >124</th>
#       <th id="T_0d839_level0_col4" class="col_heading level0 col4" >125</th>
#       <th id="T_0d839_level0_col5" class="col_heading level0 col5" >126</th>
#       <th id="T_0d839_level0_col6" class="col_heading level0 col6" >127</th>
#       <th id="T_0d839_level0_col7" class="col_heading level0 col7" >128</th>
#       <th id="T_0d839_level0_col8" class="col_heading level0 col8" >129</th>
#       <th id="T_0d839_level0_col9" class="col_heading level0 col9" >130</th>
#       <th id="T_0d839_level0_col10" class="col_heading level0 col10" >131</th>
#       <th id="T_0d839_level0_col11" class="col_heading level0 col11" >132</th>
#       <th id="T_0d839_level0_col12" class="col_heading level0 col12" >133</th>
#       <th id="T_0d839_level0_col13" class="col_heading level0 col13" >134</th>
#       <th id="T_0d839_level0_col14" class="col_heading level0 col14" >135</th>
#       <th id="T_0d839_level0_col15" class="col_heading level0 col15" >136</th>
#       <th id="T_0d839_level0_col16" class="col_heading level0 col16" >137</th>
#       <th id="T_0d839_level0_col17" class="col_heading level0 col17" >138</th>
#       <th id="T_0d839_level0_col18" class="col_heading level0 col18" >139</th>
#       <th id="T_0d839_level0_col19" class="col_heading level0 col19" >140</th>
#       <th id="T_0d839_level0_col20" class="col_heading level0 col20" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >diabetic</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d839_level0_row0" class="row_heading level0 row0" >No</th>
#       <td id="T_0d839_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_0d839_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_0d839_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_0d839_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_0d839_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_0d839_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_0d839_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_0d839_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_0d839_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_0d839_row0_col9" class="data row0 col9" >2</td>
#       <td id="T_0d839_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_0d839_row0_col11" class="data row0 col11" >2</td>
#       <td id="T_0d839_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_0d839_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_0d839_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_0d839_row0_col15" class="data row0 col15" >1</td>
#       <td id="T_0d839_row0_col16" class="data row0 col16" >2</td>
#       <td id="T_0d839_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_0d839_row0_col18" class="data row0 col18" >3</td>
#       <td id="T_0d839_row0_col19" class="data row0 col19" >1</td>
#       <td id="T_0d839_row0_col20" class="data row0 col20" >27</td>
#     </tr>
#     <tr>
#       <th id="T_0d839_level0_row1" class="row_heading level0 row1" >Yes</th>
#       <td id="T_0d839_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_0d839_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_0d839_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_0d839_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_0d839_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_0d839_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_0d839_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_0d839_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_0d839_row1_col8" class="data row1 col8" >3</td>
#       <td id="T_0d839_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_0d839_row1_col10" class="data row1 col10" >3</td>
#       <td id="T_0d839_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_0d839_row1_col12" class="data row1 col12" >1</td>
#       <td id="T_0d839_row1_col13" class="data row1 col13" >1</td>
#       <td id="T_0d839_row1_col14" class="data row1 col14" >1</td>
#       <td id="T_0d839_row1_col15" class="data row1 col15" >1</td>
#       <td id="T_0d839_row1_col16" class="data row1 col16" >2</td>
#       <td id="T_0d839_row1_col17" class="data row1 col17" >1</td>
#       <td id="T_0d839_row1_col18" class="data row1 col18" >1</td>
#       <td id="T_0d839_row1_col19" class="data row1 col19" >4</td>
#       <td id="T_0d839_row1_col20" class="data row1 col20" >28</td>
#     </tr>
#     <tr>
#       <th id="T_0d839_level0_row2" class="row_heading level0 row2" >All</th>
#       <td id="T_0d839_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_0d839_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_0d839_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_0d839_row2_col3" class="data row2 col3" >5</td>
#       <td id="T_0d839_row2_col4" class="data row2 col4" >4</td>
#       <td id="T_0d839_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_0d839_row2_col6" class="data row2 col6" >3</td>
#       <td id="T_0d839_row2_col7" class="data row2 col7" >3</td>
#       <td id="T_0d839_row2_col8" class="data row2 col8" >3</td>
#       <t

# %% [markdown]
# As we can see that the people who have high BP are smokers or are diabetic and both of these affect the blood pressure; So I really dont think that these are outliers. They are just part of the data

# %%
df['bloodpressure'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **conclusions**
# - Right skewed
# - No missing values
# - No outliers (according to me)

# %% [markdown]
# ### Claim

# %%
df['claim'].describe()
# Out:
# count     1340.000000
# mean     13252.745642
# std      12109.609288
# min       1121.870000
# 25%       4719.685000
# 50%       9369.615000
# 75%      16604.305000
# max      63770.430000
# Name: claim, dtype: float64

# %%
sns.displot(data=df, x='claim', kind='hist', color=sns.color_palette()[3]).set(title='Claim distribution')

# %%
sns.displot(data=df, x='claim', kind='kde', color=sns.color_palette()[4], fill=True).set(title='Claim distribution - KDE Plot + Rug Plot')
sns.rugplot(data=df, x='claim',color=sns.color_palette()[7])
# Out:
# <Axes: title={'center': 'Claim distribution - KDE Plot + Rug Plot'}, xlabel='claim', ylabel='Density'>

# %%
sns.catplot(data=df, y='claim', kind='box').set(title='Claim distribution - Box Plot')

# %%
df['claim'].skew()
# Out:
# 1.5167468509489237

# %%
df['claim'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **colclusions**
# - Right skewed
# - Claim amout is generally between 0 - 20,000

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Gender and Claim

# %%
sns.barplot(data=df, x='gender', y='claim').set(title='Gender vs Claim')
# Out:
# [Text(0.5, 1.0, 'Gender vs Claim')]

# %%
sns.pointplot(data=df, x='gender', y='claim', errorbar=None).set(title='Gender vs Claim - Pointplot')
# Out:
# [Text(0.5, 1.0, 'Gender vs Claim - Pointplot')]

# %% [markdown]
# **Men have more claims than women**

# %% [markdown]
# ### Claim and Diabetic

# %%
sns.barplot(data=df, x='diabetic', y='claim').set(title='Diabetic vs Claim')
# Out:
# [Text(0.5, 1.0, 'Diabetic vs Claim')]

# %%
sns.pointplot(data=df, x='diabetic', y='claim', errorbar=None).set(title='Diabetic vs Claim - Pointplot')
# Out:
# [Text(0.5, 1.0, 'Diabetic vs Claim - Pointplot')]

# %% [markdown]
# **Non - Diabetic people have more claims than non diabetic people**

# %% [markdown]
# ### Claim and Smoker

# %%
sns.barplot(data=df, x='smoker', y='claim').set(title='Smoker vs Claim')
# Out:
# [Text(0.5, 1.0, 'Smoker vs Claim')]

# %%
sns.pointplot(data=df, x='smoker', y='claim', errorbar=None).set(title='Smoker vs Claim - Pointplot')
# Out:
# [Text(0.5, 1.0, 'Smoker vs Claim - Pointplot')]

# %% [markdown]
# **Smokers have more claim than non smokers**

# %% [markdown]
# ### Claim and Region

# %%
sns.barplot(data=df, x='region', y='claim').set(title='Region vs Claim')
# Out:
# [Text(0.5, 1.0, 'Region vs Claim')]

# %%
sns.pointplot(data=df, x='region', y='claim', errorbar=None).set(title='Region vs Claim - Pointplot')
# Out:
# [Text(0.5, 1.0, 'Region vs Claim - Pointplot')]

# %% [markdown]
# NorthEast has the most number of claims.
# - This might indicate the more number of smokers are living in the NE region
# - NE might have more men than women
#
# lets check our assumptions

# %%
pd.crosstab(df['smoker'], df['region'], normalize='columns')
# Out:
# region  northeast  northwest  southeast  southwest
# smoker
# No       0.709957   0.833811   0.794582   0.815287
# Yes      0.290043   0.166189   0.205418   0.184713

# %% [markdown]
# **As you can see that most non smokers are living in the NE region, which confirms our assumption**

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### BloodPressure and Gender on Claim

# %%
import matplotlib.pyplot as plt

# %%
sns.jointplot(data=df,x='bloodpressure',y='claim',kind='scatter',hue='gender', palette='bright')
plt.suptitle('BP & Gender on Claim')
plt.subplots_adjust(top=0.90)

# %% [markdown]
# **The plot reveals that there is some correlation between claim value and bloodpressure, in both male & female groups**

# %% [markdown]
# ### Age, gender on claim

# %%
sns.jointplot(data=df,x='age',y='claim',kind='scatter',hue='gender', palette='bright')
plt.suptitle('Age & Gender on Claim')
plt.subplots_adjust(top=0.90)

# %% [markdown]
# **Nothing significant can be observed from this**

# %% [markdown]
# ### Age and Diabetes on claim

# %%
sns.jointplot(data=df,x='age',y='claim',kind='scatter',hue='diabetic', palette='bright')
plt.suptitle('Age & Diabetic on Claim')
plt.subplots_adjust(top=0.90)

# %% [markdown]
# **Nothing significant can be observed**

# %% [markdown]
# ### Age and smoker on claim

# %%
sns.jointplot(data=df,x='age',y='claim',kind='scatter',hue='smoker', palette='bright')
plt.suptitle('Age & Smoker on Claim')
plt.subplots_adjust(top=0.90)

# %% [markdown]
# **This plot shows that smoker have a high claim value**

# %% [markdown]
# ### End of EDA
#
# If you have any suggestions, please do drop it in the comments
